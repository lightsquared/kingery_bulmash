# %%
import kingery_bulmash as kb
import numpy as np

distance = np.arange(0.134, 100, 0.1)
weight = 1 #lb
units = 'fpd'
charge = 'hsb'

# %%
kb.ip(distance, weight, units, charge)
# Out:
# (array([2.81031596e+04, 1.41522395e+04, 8.80903183e+03, 6.05689639e+03,
#         4.38728685e+03, 3.28342315e+03, 2.51702141e+03, 1.96779210e+03,
#         1.56489299e+03, 1.26366370e+03, 1.03470716e+03, 8.58091036e+02,
#         7.19995362e+02, 6.10662022e+02, 5.23091478e+02, 4.52191357e+02,
#         3.94208320e+02, 3.46342300e+02, 3.06480575e+02, 2.73011944e+02,
#         2.44695259e+02, 2.20565300e+02, 1.99864664e+02, 1.81993951e+02,
#         1.66474971e+02, 1.52923322e+02, 1.41027753e+02, 1.30534520e+02,
#         1.21235410e+02, 1.12958521e+02, 1.05561090e+02, 9.89238998e+01,
#         9.29468645e+01, 8.75455356e+01, 8.26483168e+01, 7.81942302e+01,
#         7.41311144e+01, 7.04141638e+01, 6.70047380e+01, 6.38693863e+01,
#         6.09790457e+01, 5.83083770e+01, 5.58352139e+01, 5.35401039e+01,
#         5.14059231e+01, 4.94175535e+01, 4.75616100e+01, 4.58262095e+01,
#         4.42007748e+01, 4.26758674e+01, 4.12430443e+01, 3.98947355e+01,
# ...
